# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('train.csv')
flights=sns.load_dataset('flights')
iris=sns.load_dataset('iris')
tips=sns.load_dataset('tips')
flights.head(3)
iris.head(2)
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
print(df.head(2))
# train dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Scatterplot(Numerical-Numerical)

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Barplot(Numerical-Categorical)

# %%
sns.barplot(x=df['Pclass'],y=df['Fare'],hue=df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Boxplot(Numerical-Categorical)

# %%
sns.boxplot(x=df['Sex'],y=df['Age'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('train.csv')
flights=sns.load_dataset('flights')
iris=sns.load_dataset('iris')
tips=sns.load_dataset('tips')
sns.histplot(df[df['Survived']==0]['Age'],kde=True)
sns.histplot(df[df['Survived']==1]['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# heatmap(c-c)

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# CLustermap(cat.-cate.)

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']))

# %%
sns.pairplot(iris,hue='species')

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_9056\2230379170.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>
