# %%
import pandas as pd
import numpy as np
df=pd.read_csv('cars.csv')
df.sample(4)
# Out:
#        brand  km_driven    fuel         owner  selling_price
# 5390  Maruti      80000  Diesel  Second Owner         530000
# 4499   Honda       5000  Petrol   First Owner        1227000
# 6973     BMW       7500  Diesel   First Owner        5400000
# 4633  Maruti      51146  Diesel   First Owner         800000

# %%
df.brand.nunique()
# Out:
# 32

# %%
df.fuel.value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df.owner.value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# 1. One Hot Encoding using pandas

# %%
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# 0           False               True                       False
# 1           False              False                       False
# 2            True              False                       False
# 3           False               True                       False
# 4            True               True                       False
# ...           ...                ...                         ...
# 8123         True               True                       False
# 8124        False              False                        True
# 8125        False               True                       False
# 8126        False               True                       False
# 8127        False               True                       False
#
#       owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                  False                 False              False
# 1                   True                 False              False
# 2                  False                 False               True
# 3                  False                 False              False
# 4                  False                 False              False
# ...                  ...                   ...                ...
# 8123               False                 False              False
# 8124               False                 False              False
# 8125               False                 False              False
# 8126               False                 False              False
# 8127               False                 False              False
#
# [8128 rows x 12 columns]

# %% [markdown]
# k-1 OHE

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                          False               False                 False
# 1                          False                True                 False
# 2                          False               False                 False
# 3                          False               False                 False
# 4                          False               False                 False
# ...                          ...                 ...                   ...
# 8123                       False               False                 False
# 8124                        True               False                 False
# 8125                       False               False                 False
# 8126                       False               False                 False
# 8127                       False               False                 False
#
#       owner_Third Owner
# 0                 False
# 1                 False
# 2                  True
# 3                 False
# 4                 False
# ...                 ...
# 8123              False
# 8124              False
# 8125              False
# 8126              False
# 8127              False
#
# [8128 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=True)
X_test.head()
# Out:
#          brand  km_driven    fuel        owner
# 1392  Mahindra      80000  Diesel  First Owner
# 7778      Tata      45000  Diesel  First Owner
# 3727   Hyundai      60000  Diesel  First Owner
# 6630      Tata      15000  Petrol  First Owner
# 103     Maruti     100000  Petrol  Third Owner

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first',dtype=np.int32)

# %%
X_train_new=ohe.fit_transform(X_train[['fuel','owner']]).toarray()

# %%
X_test_new=ohe.fit_transform(X_test[['fuel','owner']]).toarray()

# %%
X_test_new.shape
# if drop= first then ans change
# Out:
# (1626, 8)

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new)).shape
# Out:
# (6502, 11)

# %% [markdown]
# OHE with top categories

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold=100

# %%
repl=counts[counts<=threshold].index
pd.get_dummies(df['brand'].replace(repl,'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 6923  False      False  False  False    False     False    True    False
# 1178  False       True  False  False    False     False   False    False
# 4038  False      False  False  False    False     False   False    False
# 4421  False      False  False  False    False     False    True    False
# 4107  False      False  False   True    False     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 6923  False  False   False       False     False
# 1178  False  False   False       False     False
# 4038  False   True   False       False     False
# 4421  False  False   False       False     False
# 4107  False  False   False       False     False
